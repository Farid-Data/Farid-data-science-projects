# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from pandas.api.types import is_datetime64_dtype, is_numeric_dtype, is_categorical_dtype

# %%
from src.clean import DataCleaner
from src.loader import DataLoader

# %%
data = DataLoader()
clean = DataCleaner()
df_order = data.load_orders()
check = clean.report(df_order)
for key, value in check['column_statistics'].items():
    print(key, ": ", value,end="\n\n")

# %%
result = {}
for col in df_order.columns:
    result[col] = df_order[col].value_counts()

for key, value in result.items():
    print(key, ": ", value,end="\n\n")
