# %%
from torchvision.datasets import (
    # MNIST,
    # FashionMNIST,
    CIFAR10,
    CIFAR100,
    Flowers102,
)

DATASET_DIR = "../data"

# print("Downloading MNIST...")
# MNIST(root=DATASET_DIR, train=True, download=True)
# MNIST(root=DATASET_DIR, train=False, download=True)

# print("Downloading Fashion-MNIST...")
# FashionMNIST(root=DATASET_DIR, train=True, download=True)
# FashionMNIST(root=DATASET_DIR, train=False, download=True)

print("Downloading CIFAR-10...")
CIFAR10(root=DATASET_DIR, train=True, download=True)
CIFAR10(root=DATASET_DIR, train=False, download=True)

print("Downloading CIFAR-100...")
CIFAR100(root=DATASET_DIR, train=True, download=True)
CIFAR100(root=DATASET_DIR, train=False, download=True)

print("Downloading Flowers102...")
Flowers102(root=DATASET_DIR, split="train", download=True)
Flowers102(root=DATASET_DIR, split="test", download=True)
Flowers102(root=DATASET_DIR, split="val", download=True)

print("All datasets downloaded successfully!")
# Out:
# ...
# 100%|██████████| 170M/170M [38:28<00:00, 73.8kB/s]
# ...
# 100%|██████████| 169M/169M [39:27<00:00, 71.4kB/s]
# ...
# 100%|██████████| 345M/345M [03:43<00:00, 1.54MB/s]
# 100%|██████████| 502/502 [00:00<00:00, 586kB/s]
# 100%|██████████| 15.0k/15.0k [00:00<00:00, 11.8MB/s]
# All datasets downloaded successfully!
